# %%
import sqlite3

# %%
import os, sys
sys.path.append("../common/")
from python_tools import *

# %%
time_db_file = "/Users/wketchum/MicroBooNE_Data/MCC9/time.db"

# %%
conn = sqlite3.connect(time_db_file)
df = pd.read_sql_query("select * from TimeModule;", conn)

# %%
df
# Out:
#     Run  SubRun  Event      Path     ModuleLabel  \
# 0     1       0      1  simulate             rns
# 1     1       0      1  simulate        largeant
# 2     1       0      1  simulate      ionization
# 3     1       0      1  simulate          mcreco
# 4     1       0      1  simulate  TriggerResults
# 5     1       0      1  end_path            out1
# 6     1       0      1  end_path            out1
# 7     1       0      2  simulate             rns
# 8     1       0      2  simulate        largeant
# 9     1       0      2  simulate      ionization
# 10    1       0      2  simulate          mcreco
# 11    1       0      2  simulate  TriggerResults
# 12    1       0      2  end_path            out1
# 13    1       0      2  end_path            out1
# 14    1       0      3  simulate             rns
# 15    1       0      3  simulate        largeant
# 16    1       0      3  simulate      ionization
# 17    1       0      3  simulate          mcreco
# ...

# %%
df.query("ModuleLabel=='largeant'")[["Event","Time"]]
# Out:
#     Event       Time
# 1       1  25.918813
# 8       2   1.252752
# 15      3   0.208549
# 22      4   0.984279
# 29      5   0.117340
# 36      6   0.660351
# 43      7   1.636361
# 50      8   1.287125
# 57      9   0.114022
# 64     10   0.790067

# %%
# %matplotlib notebook

# %%
fig,ax = plt.subplots()
ax.set_xscale("log", nonposx='clip')
ax.hist(df.query("ModuleLabel=='largeant'")["Time"],bins=np.logspace(np.log10(0.01),np.log10(100.0), 50),**pltops_hist)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
